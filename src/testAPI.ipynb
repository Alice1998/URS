# %%
from openai import OpenAI

client = OpenAI(api_key="sk-z7CYuGnSpejt4nxcDd2e838c172d45DaAa1fDdDa2e1f7c31",
                base_url='https://yeysai.com/v1')

response = client.chat.completions.create(
    model='gpt-4-0125-preview',
    messages=[
        # {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": 'hello world'},
    ]
)
print(response.choices[0].message.content)
# Out:
# Hello! How can I assist you today?

# %%
from openai import OpenAI

# client = OpenAI(api_key="sk-z7CYuGnSpejt4nxcDd2e838c172d45DaAa1fDdDa2e1f7c31",
#                 base_url='https://yeysai.com/v1')
client=OpenAI(api_key="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",organization="org-3ikSNn1oZVMn9xIEvRfarT5e")

response = client.chat.completions.create(
    model='gpt-4-0125-preview',
    messages=[
        # {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": 'hello world'},
    ]
)
print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/miniconda3/envs/debias/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/miniconda3/envs/debias/lib/python3.8/site-packages/httpcore/_backends/sync.py in connect_tcp(self, host, port, timeout, local_address, socket_options)
#     205         with map_exceptions(exc_map):
# --> 206             sock = socket.create_connection(
#     207                 address,
#
# ~/miniconda3/envs/debias/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# ~/miniconda3/envs/debias/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
# ...
